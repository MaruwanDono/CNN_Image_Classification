# %% [markdown]
# # Deep learning for computer vision
#
#
# This notebook will teach you to build and train convolutional networks for image recognition. Brace yourselves.

# %% [markdown]
# # CIFAR dataset
# This week, we shall focus on the image recognition problem on cifar10 dataset
# * 60k images of shape 3x32x32
# * 10 different classes: planes, dogs, cats, trucks, etc.
#
# <img src="https://github.com/yandexdataschool/Practical_DL/blob/fall23/week03_convnets/cifar10.jpg?raw=1" style="width:80%">

# %%
# when running in colab, un-comment this
# !wget https://raw.githubusercontent.com/yandexdataschool/Practical_DL/fall19/week03_convnets/cifar.py
# Out:
# --2024-10-08 07:21:51--  https://raw.githubusercontent.com/yandexdataschool/Practical_DL/fall19/week03_convnets/cifar.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2396 (2.3K) [text/plain]
# Saving to: ‘cifar.py’
#
# cifar.py            100%[===================>]   2.34K  --.-KB/s    in 0s
#
# 2024-10-08 07:21:51 (48.6 MB/s) - ‘cifar.py’ saved [2396/2396]

# %%
import numpy as np
from cifar import load_cifar10
X_train, y_train, X_val, y_val, X_test, y_test = load_cifar10("cifar_data")

class_names = np.array(['airplane', 'automobile', 'bird', 'cat', 'deer',
                        'dog', 'frog', 'horse', 'ship', 'truck'])

print(X_train.shape,y_train.shape)
# Out:
# Dataset not found. Downloading...
# (40000, 3, 32, 32) (40000,)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import time

plt.figure(figsize=[12,10])
for i in range(12):
    plt.subplot(3,4,i+1)
    plt.xlabel(class_names[y_train[i]])
    plt.imshow(np.transpose(X_train[i],[1,2,0]))

# %% [markdown]
# # Building a network
#
# Simple neural networks with layers applied on top of one another can be implemented as `torch.nn.Sequential` - just add a list of pre-built modules and let it train.

# %%
import torch, torch.nn as nn
import torch.nn.functional as F

# a special module that converts [batch, channel, w, h] to [batch, units]
class Flatten(nn.Module):
    def forward(self, input):
        return input.view(input.size(0), -1)

# %% [markdown]
# Let's start with a dense network for our baseline:

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = nn.Sequential(
    # [3, 32, 32]
    nn.Conv2d(3, 32, kernel_size=(5, 5)),
    # [32, 28, 28]

    nn.MaxPool2d((2, 2)),
    # [32, 14, 14]
    nn.ReLU(),

    nn.Conv2d(32, 64, kernel_size=(5, 5)),
    # [64, 10, 10]
    nn.Flatten(),
    nn.Linear(64 * 10 * 10, 64),
    nn.ReLU(),
    nn.Linear(64, 10),
).to(device=device)

# %% [markdown]
# As in our basic tutorial, we train our model with negative log-likelihood aka crossentropy.

# %%
def compute_loss(X_batch, y_batch):
    X_batch = torch.as_tensor(X_batch, dtype=torch.float32, device=device)
    y_batch = torch.as_tensor(y_batch, dtype=torch.int64, device=device)
    logits = model(X_batch)
    return F.cross_entropy(logits, y_batch).mean()

# %%
# example
loss = compute_loss(X_train[:5], y_train[:5])

# %% [markdown]
# ### Training on minibatches
# * We got 40k images, that's way too many for a full-batch SGD. Let's train on minibatches instead
# * Below is a function that splits the training sample into minibatches

# %%
# An auxilary function that returns mini-batches for neural network training
def iterate_minibatches(X, y, batchsize):
    indices = np.random.permutation(np.arange(len(X)))
    for start in range(0, len(indices), batchsize):
        ix = indices[start: start + batchsize]
        yield X[ix], y[ix]

# %%
opt = torch.optim.SGD(model.parameters(), lr=0.01)

train_loss = []
val_accuracy = []

# %%
import time
num_epochs = 30 # total amount of full passes over training data
batch_size = 50  # number of samples processed in one SGD iteration

best_accuracy = -np.inf
best_epoch = -1

for epoch in range(num_epochs):
    # In each epoch, we do a full pass over the training data:
    start_time = time.time()
    model.train(True) # enable dropout / batch_norm training behavior
    for X_batch, y_batch in iterate_minibatches(X_train, y_train, batch_size):
        # train on batch
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.cpu().data.numpy())

    # And a full pass over the validation data:
    model.train(False) # disable dropout / use averages for batch_norm
    for X_batch, y_batch in iterate_minibatches(X_val, y_val, batch_size):
        logits = model(torch.as_tensor(X_batch, dtype=torch.float32, device=device))
        y_pred = logits.max(1)[1].cpu().data.numpy()
        val_accuracy.append(np.mean(y_batch == y_pred))


    # Then we print the results for this epoch:
    print("Epoch {} of {} took {:.3f}s".format(
        epoch + 1, num_epochs, time.time() - start_time))
    print("  training loss (in-iteration): \t{:.6f}".format(
        np.mean(train_loss[-len(X_train) // batch_size :])))
    print("  validation accuracy: \t\t\t{:.2f} %".format(
        np.mean(val_accuracy[-len(X_val) // batch_size :]) * 100))
# Out:
# Epoch 1 of 30 took 53.570s
#   training loss (in-iteration): 	2.098150
#   validation accuracy: 			33.34 %
# Epoch 2 of 30 took 55.028s
#   training loss (in-iteration): 	1.824819
#   validation accuracy: 			38.77 %
# Epoch 3 of 30 took 51.928s
#   training loss (in-iteration): 	1.648845
#   validation accuracy: 			42.58 %
# Epoch 4 of 30 took 51.610s
#   training loss (in-iteration): 	1.537492
#   validation accuracy: 			46.56 %
# Epoch 5 of 30 took 51.394s
#   training loss (in-iteration): 	1.456454
#   validation accuracy: 			49.65 %
# Epoch 6 of 30 took 51.192s
#   training loss (in-iteration): 	1.381950
#   validation accuracy: 			51.12 %
# Epoch 7 of 30 took 50.317s
#   training loss (in-iteration): 	1.318943
#   validation accuracy: 			53.10 %
# Epoch 8 of 30 took 51.277s
#   training loss (in-iteration): 	1.271653
#   validation accuracy: 			55.31 %
# Epoch 9 of 30 took 51.509s
#   training loss (in-iteration): 	1.229475
#   validation accuracy: 			57.00 %
# Epoch 10 of 30 took 51.934s
#   training loss (in-iteration): 	1.189835
#   validation accuracy: 			57.33 %
# Epoch 11 of 30 took 51.654s
#   training loss (in-iteration): 	1.153567
#   validation accuracy: 			58.80 %
# Epoch 12 of 30 took 51.487s
#   training loss (in-iteration): 	1.119168
#   validation accuracy: 			60.21 %
# Epoch 13 of 30 took 51.381s
#   training loss (in-iteration): 	1.083548
#   validation accuracy: 			61.19 %
# Epoch 14 of 30 took 50.505s
#   training loss (in-iteration): 	1.050361
#   validation accuracy: 			61.72 %
# Epoch 15 of 30 took 51.789s
#   training loss (in-iteration): 	1.017559
#   validation accuracy: 			60.69 %
# Epoch 16 of 30 took 51.971s
#   training loss (in-iteration): 	0.989553
#   validation accuracy: 			63.73 %
# Epoch 17 of 30 took 51.859s
#   training loss (in-iteration): 	0.961896
#   validation accuracy: 			63.83 %
# Epoch 18 of 30 took 51.785s
#   training loss (in-iteration): 	0.937741
#   validation accuracy: 			64.22 %
# Epoch 19 of 30 took 51.327s
#   training loss (in-iteration): 	0.909995
#   validation accuracy: 			64.37 %
# Epoch 20 of 30 took 51.590s
#   training loss (in-iteration): 	0.887622
#   validation accuracy: 			64.38 %
# Epoch 21 of 30 took 50.877s
#   training loss (in-iteration): 	0.865724
#   validation accuracy: 			65.93 %
# Epoch 22 of 30 took 51.487s
#   training loss (in-iteration): 	0.843120
#   validation accuracy: 			65.22 %
# Epoch 23 of 30 took 51.729s
#   training loss (in-iteration): 	0.819752
#   validation accuracy: 			65.43 %
# Epoch 24 of 30 took 51.447s
#   training loss (in-iteration): 	0.802428
#   validation accuracy: 			66.13 %
# Epoch 25 of 30 took 51.363s
#   training loss (in-iteration): 	0.779545
#   validation accuracy: 			64.98 %
# Epoch 26 of 30 took 51.131s
#   training loss (in-iteration): 	0.760065
#   validation accuracy: 			66.34 %
# Epoch 27 of 30 took 51.505s
#   training loss (in-iteration): 	0.741908
#   validation accuracy: 			66.57 %
# Epoch 28 of 30 took 50.701s
#   training loss (in-iteration): 	0.721402
#   validation accuracy: 			66.11 %
# Epoch 29 of 30 took 51.356s
#   training loss (in-iteration): 	0.702324
#   validation accuracy: 			66.85 %
# Epoch 30 of 30 took 51.572s
#   training loss (in-iteration): 	0.685256
#   validation accuracy: 			67.01 %

# %% [markdown]
# Don't wait for full 100 epochs. You can interrupt training after 5-20 epochs once validation accuracy stops going up.
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ### Final test

# %%
model.train(False) # disable dropout / use averages for batch_norm
test_batch_acc = []
for X_batch, y_batch in iterate_minibatches(X_test, y_test, 500):
    logits = model(torch.as_tensor(X_batch, dtype=torch.float32, device=device))
    y_pred = logits.max(1)[1].cpu().data.numpy()
    test_batch_acc.append(np.mean(y_batch == y_pred))

test_accuracy = np.mean(test_batch_acc)

print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_accuracy * 100))

if test_accuracy * 100 > 95:
    print("Double-check, than consider applying for NIPS'17. SRSly.")
elif test_accuracy * 100 > 90:
    print("U'r freakin' amazin'!")
elif test_accuracy * 100 > 80:
    print("Achievement unlocked: 110lvl Warlock!")
elif test_accuracy * 100 > 70:
    print("Achievement unlocked: 80lvl Warlock!")
elif test_accuracy * 100 > 60:
    print("Achievement unlocked: 70lvl Warlock!")
elif test_accuracy * 100 > 50:
    print("Achievement unlocked: 60lvl Warlock!")
else:
    print("We need more magic! Follow instructons below")
# Out:
# Final results:
#   test accuracy:		66.46 %
# Achievement unlocked: 70lvl Warlock!

# %% [markdown]
# ## Task I: small convolution net
# ### First step
#
# Let's create a mini-convolutional network with roughly such architecture:
# * Input layer
# * 3x3 convolution with 10 filters and _ReLU_ activation
# * 2x2 pooling (or set previous convolution stride to 3)
# * Flatten
# * Dense layer with 100 neurons and _ReLU_ activation
# * 10% dropout
# * Output dense layer.
#
#
# __Convolutional layers__ in torch are just like all other layers, but with a specific set of parameters:
#
# __`...`__
#
# __`model.add_module('conv1', nn.Conv2d(in_channels=3, out_channels=10, kernel_size=3)) # convolution`__
#
# __`model.add_module('pool1', nn.MaxPool2d(2)) # max pooling 2x2`__
#
# __`...`__
#
#
# Once you're done (and compute_loss no longer raises errors), train it with __Adam__ optimizer with default params (feel free to modify the code above).
#
# If everything is right, you should get at least __50%__ validation accuracy.

# %% [markdown]
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# __Hint:__ If you don't want to compute shapes by hand, just plug in any shape (e.g. 1 unit) and run compute_loss. You will see something like this:
#
# __`RuntimeError: size mismatch, m1: [5 x 1960], m2: [1 x 64] at /some/long/path/to/torch/operation`__
#
# See the __1960__ there? That's your actual input shape.
#
# ## Task 2: adding normalization
#
# * Add batch norm (with default params) between convolution and ReLU
#   * nn.BatchNorm*d (1d for dense, 2d for conv)
#   * usually better to put them after linear/conv but before nonlinearity
# * Re-train the network with the same optimizer, it should get at least 60% validation accuracy at peak.

# %% [markdown]
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
# ## Task 3: Data Augmentation
#
# There's a powerful torch tool for image preprocessing useful to do data preprocessing and augmentation.
#
# Here's how it works: we define a pipeline that
# * makes random crops of data (augmentation)
# * randomly flips image horizontally (augmentation)
# * then normalizes it (preprocessing)

# %%
del model, opt, train_loss, val_accuracy

# %%
from torchvision import transforms
means = np.array((0.4914, 0.4822, 0.4465))
stds = np.array((0.2023, 0.1994, 0.2010))

transform_augment = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomRotation([-30, 30]),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(means, stds),
])

# %%
from torchvision.datasets import CIFAR10
from torch.utils.data import DataLoader, random_split
train_loader = CIFAR10("./cifar_data/", train=True, transform=transform_augment)

#Split the dataset into training and validation datasets (80% train, 20% val)
train_size = int(0.8 * len(train_loader))
val_size = len(train_loader) - train_size
train_dataset, val_dataset = random_split(train_loader, [train_size, val_size])

#Create DataLoaders for training and validation
train_batch_gen = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=1)
val_batch_gen = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=1)

# %%
for (x_batch, y_batch) in train_batch_gen:

    print('X:', type(x_batch), x_batch.shape)
    print('y:', type(y_batch), y_batch.shape)

    for i, img in enumerate(x_batch.numpy()[:8]):
        plt.subplot(2, 4, i+1)
        plt.imshow(img.transpose([1,2,0]) * stds + means )


    break
    #raise NotImplementedError("Plese use this code in your training loop")
    # TODO use this in your training loop
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# X: <class 'torch.Tensor'> torch.Size([32, 3, 32, 32])
# y: <class 'torch.Tensor'> torch.Size([32])
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# The CNN as recommended by the previous tasks should be something like this:

# %%
model = nn.Sequential(
    nn.Conv2d(in_channels=3, out_channels=10, kernel_size=3),  # 3x3 convolution with 10 filters
    nn.BatchNorm2d(10),  # Batch Norm after convolution
    nn.ReLU(),
    nn.MaxPool2d(2),  # 2x2 pooling
    Flatten(),
    nn.Linear(10 * 15 * 15, 100),  # Adjust input size for flattened layer
    nn.BatchNorm1d(100),  # Batch Norm after dense layer
    nn.ReLU(),
    nn.Dropout(0.1),  # 10% dropout
    nn.Linear(100, 10)  # Output dense layer with 10 classes
).to(device=device)

# Training loop (uses Adam optimizer)
opt = torch.optim.Adam(model.parameters(), lr=0.001)

train_loss = []
val_accuracy = []

num_epochs = 50
batch_size = 50
best_accuracy = -np.inf
best_epoch = -1

for epoch in range(num_epochs):
    start_time = time.time()
    model.train(True)
    #for X_batch, y_batch in iterate_minibatches(X_train, y_train, batch_size):
    for X_batch, y_batch in train_batch_gen:
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.cpu().data.numpy())

    model.train(False)
    for X_batch, y_batch in val_batch_gen:
        #X_batch = X_batch.to(device)
        #y_batch = y_batch.to(device)
        logits = model(torch.as_tensor(X_batch, dtype=torch.float32, device=device))
        y_pred = logits.max(1)[1].cpu().data.numpy()
        val_accuracy.append(np.mean(y_batch.data.numpy() == y_pred))

    print(f"Epoch {epoch + 1} of {num_epochs} took {time.time() - start_time:.3f}s")
    print(f"  training loss (in-iteration): \t{np.mean(train_loss[-len(X_train) // batch_size :]):.6f}")
    print(f"  validation accuracy: \t\t\t{np.mean(val_accuracy[-len(X_val) // batch_size :]) * 100:.2f} %")
# Out:
# Epoch 1 of 50 took 45.278s
#   training loss (in-iteration): 	1.612628
#   validation accuracy: 			45.59 %
# Epoch 2 of 50 took 46.168s
#   training loss (in-iteration): 	1.513027
#   validation accuracy: 			48.16 %
# Epoch 3 of 50 took 44.939s
#   training loss (in-iteration): 	1.465791
#   validation accuracy: 			49.64 %
# Epoch 4 of 50 took 45.492s
#   training loss (in-iteration): 	1.438190
#   validation accuracy: 			50.88 %
# Epoch 5 of 50 took 45.356s
#   training loss (in-iteration): 	1.407848
#   validation accuracy: 			49.67 %
# Epoch 6 of 50 took 44.446s
#   training loss (in-iteration): 	1.398424
#   validation accuracy: 			53.84 %
# Epoch 7 of 50 took 44.333s
#   training loss (in-iteration): 	1.385482
#   validation accuracy: 			52.89 %
# Epoch 8 of 50 took 44.425s
#   training loss (in-iteration): 	1.366277
#   validation accuracy: 			52.62 %
# Epoch 9 of 50 took 44.602s
#   training loss (in-iteration): 	1.357464
#   validation accuracy: 			53.11 %
# Epoch 10 of 50 took 44.583s
#   training loss (in-iteration): 	1.353286
#   validation accuracy: 			55.41 %
# Epoch 11 of 50 took 45.915s
#   training loss (in-iteration): 	1.346040
#   validation accuracy: 			54.50 %
# Epoch 12 of 50 took 43.919s
#   training loss (in-iteration): 	1.336192
#   validation accuracy: 			54.44 %
# Epoch 13 of 50 took 44.496s
#   training loss (in-iteration): 	1.323900
#   validation accuracy: 			55.97 %
# Epoch 14 of 50 took 44.195s
#   training loss (in-iteration): 	1.324526
#   validation accuracy: 			55.16 %
# Epoch 15 of 50 took 44.098s
#   training loss (in-iteration): 	1.315674
#   validation accuracy: 			56.52 %
# Epoch 16 of 50 took 44.139s
#   training loss (in-iteration): 	1.316080
#   validation accuracy: 			56.20 %
# Epoch 17 of 50 took 44.669s
#   training loss (in-iteration): 	1.308696
#   validation accuracy: 			56.11 %
# Epoch 18 of 50 took 45.440s
#   training loss (in-iteration): 	1.301427
#   validation accuracy: 			56.94 %
# Epoch 19 of 50 took 44.493s
#   training loss (in-iteration): 	1.292769
#   validation accuracy: 			56.48 %
# Epoch 20 of 50 took 43.772s
#   training loss (in-iteration): 	1.297320
#   validation accuracy: 			56.20 %
# Epoch 21 of 50 took 44.313s
#   training loss (in-iteration): 	1.297040
#   validation accuracy: 			56.47 %
# Epoch 22 of 50 took 44.116s
#   training loss (in-iteration): 	1.301471
#   validation accuracy: 			57.27 %
# Epoch 23 of 50 took 45.898s
#   training loss (in-iteration): 	1.287775
#   validation accuracy: 			56.38 %
# Epoch 24 of 50 took 44.376s
#   training loss (in-iteration): 	1.282692
#   validation accuracy: 			56.55 %
# Epoch 25 of 50 took 44.200s
#   training loss (in-iteration): 	1.278277
#   validation accuracy: 			56.88 %
# Epoch 26 of 50 took 43.956s
#   training loss (in-iteration): 	1.279486
#   validation accuracy: 			56.59 %
# Epoch 27 of 50 took 44.270s
#   training loss (in-iteration): 	1.281082
#   validation accuracy: 			57.70 %
# Epoch 28 of 50 took 44.807s
#   training loss (in-iteration): 	1.268892
#   validation accuracy: 			58.41 %
# Epoch 29 of 50 took 45.308s
#   training loss (in-iteration): 	1.278329
#   validation accuracy: 			55.70 %
# Epoch 30 of 50 took 45.152s
#   training loss (in-iteration): 	1.271413
#   validation accuracy: 			57.66 %
# Epoch 31 of 50 took 44.616s
#   training loss (in-iteration): 	1.264516
#   validation accuracy: 			57.50 %
# Epoch 32 of 50 took 44.111s
#   training loss (in-iteration): 	1.261402
#   validation accuracy: 			58.22 %
# Epoch 33 of 50 took 44.763s
#   training loss (in-iteration): 	1.258219
#   validation accuracy: 			56.48 %
# Epoch 34 of 50 took 44.528s
#   training loss (in-iteration): 	1.260258
#   validation accuracy: 			57.92 %
# Epoch 35 of 50 took 45.235s
#   training loss (in-iteration): 	1.254010
#   validation accuracy: 			58.73 %
# Epoch 36 of 50 took 45.615s
#   training loss (in-iteration): 	1.251645
#   validation accuracy: 			58.94 %
# Epoch 37 of 50 took 44.401s
#   training loss (in-iteration): 	1.250732
#   validation accuracy: 			58.47 %
# Epoch 38 of 50 took 44.292s
#   training loss (in-iteration): 	1.255737
#   validation accuracy: 			58.27 %
# Epoch 39 of 50 took 45.269s
#   training loss (in-iteration): 	1.251647
#   validation accuracy: 			58.89 %
# Epoch 40 of 50 took 44.596s
#   training loss (in-iteration): 	1.253504
#   validation accuracy: 			59.31 %
# Epoch 41 of 50 took 45.931s
#   training loss (in-iteration): 	1.253134
#   validation accuracy: 			58.11 %
# Epoch 42 of 50 took 44.353s
#   training loss (in-iteration): 	1.246528
#   validation accuracy: 			58.66 %
# Epoch 43 of 50 took 44.443s
#   training loss (in-iteration): 	1.241504
#   validation accuracy: 			58.83 %
# Epoch 44 of 50 took 44.073s
#   training loss (in-iteration): 	1.242579
#   validation accuracy: 			59.08 %
# Epoch 45 of 50 took 44.321s
#   training loss (in-iteration): 	1.240049
#   validation accuracy: 			58.69 %
# Epoch 46 of 50 took 44.534s
#   training loss (in-iteration): 	1.241072
#   validation accuracy: 			58.77 %
# Epoch 47 of 50 took 45.712s
#   training loss (in-iteration): 	1.237104
#   validation accuracy: 			59.08 %
# Epoch 48 of 50 took 44.587s
#   training loss (in-iteration): 	1.235701
#   validation accuracy: 			58.45 %
# Epoch 49 of 50 took 44.767s
#   training loss (in-iteration): 	1.241617
#   validation accuracy: 			59.09 %
# Epoch 50 of 50 took 44.480s
#   training loss (in-iteration): 	1.232706
#   validation accuracy: 			59.36 %

# %% [markdown]
# When testing, we don't need random crops, just normalize with same statistics.

# %%
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(means, stds),
])

#Define test loader with the transform_test
test_loader = CIFAR10("./cifar_data/", train=False, transform=transform_test)
test_batch_gen = DataLoader(test_loader, batch_size=32, shuffle=False, num_workers=1)

# %%
model.train(False) # disable dropout / use averages for batch_norm
test_batch_acc = []
#for X_batch, y_batch in iterate_minibatches(X_test, y_test, 500):
for X_batch, y_batch in test_batch_gen:
    logits = model(torch.as_tensor(X_batch, dtype=torch.float32, device=device))
    y_pred = logits.max(1)[1].cpu().data.numpy()
    test_batch_acc.append(np.mean(y_batch.data.numpy() == y_pred))

test_accuracy = np.mean(test_batch_acc)

print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_accuracy * 100))

if test_accuracy * 100 > 95:
    print("Double-check, than consider applying for NIPS'17. SRSly.")
elif test_accuracy * 100 > 90:
    print("U'r freakin' amazin'!")
elif test_accuracy * 100 > 80:
    print("Achievement unlocked: 110lvl Warlock!")
elif test_accuracy * 100 > 70:
    print("Achievement unlocked: 80lvl Warlock!")
elif test_accuracy * 100 > 60:
    print("Achievement unlocked: 70lvl Warlock!")
elif test_accuracy * 100 > 50:
    print("Achievement unlocked: 60lvl Warlock!")
else:
    print("We need more magic! Follow instructons below")
# Out:
# Final results:
#   test accuracy:		63.65 %
# Achievement unlocked: 70lvl Warlock!

# %% [markdown]
# #The Quest For A Better Network
#
# In this assignment you will build a monster network to solve CIFAR10 image classification.

# %% [markdown]
# (please read it at least diagonally)
#
# * The ultimate quest is to create a network that has as high __accuracy__ as you can push it.
# * There is a __mini-report__ at the end that you will have to fill in. We recommend reading it first and filling it while you iterate.
#
#
# ## Restrictions
# * Please do NOT use pre-trained networks for this assignment until you reach 80%.
#  * In other words, base milestones must be beaten without pre-trained nets (and such net must be present in the e-mail). After that, you can use whatever you want.
# * you __can__ use validation data for training, but you __can't'__ do anything with test data apart from running the evaluation procedure.
#
# ## Tips on what can be done:
#
#
#  * __Network size__
#    * MOAR neurons,
#    * MOAR layers, ([torch.nn docs](http://pytorch.org/docs/master/nn.html))
#
#    * Nonlinearities in the hidden layers
#      * tanh, relu, leaky relu, etc
#    * Larger networks may take more epochs to train, so don't discard your net just because it could didn't beat the baseline in 5 epochs.
#
#
# ### The main rule of prototyping: one change at a time
#    * By now you probably have several ideas on what to change. By all means, try them out! But there's a catch: __never test several new things at once__.
#
#
# ### Optimization
#    * Training for 100 epochs regardless of anything is probably a bad idea.
#    * Some networks converge over 5 epochs, others - over 500.
#    * Way to go: stop when validation score is 10 iterations past maximum
#    * You should certainly use adaptive optimizers
#      * rmsprop, nesterov_momentum, adam, adagrad and so on.
#      * Converge faster and sometimes reach better optima
#      * It might make sense to tweak learning rate/momentum, other learning parameters, batch size and number of epochs
#    * __BatchNormalization__ (nn.BatchNorm2d) for the win!
#      * Sometimes more batch normalization is better.
#    * __Regularize__ to prevent overfitting
#      * Add some L2 weight norm to the loss function, PyTorch will do the rest
#        * Can be done manually or with weight_decay parameter of a optimizer ([for example SGD's doc](https://pytorch.org/docs/stable/optim.html#torch.optim.SGD)).
#      * Dropout (`nn.Dropout`) - to prevent overfitting
#        * Don't overdo it. Check if it actually makes your network better
#
# ### Convolution architectures
#    * This task __can__ be solved by a sequence of convolutions and poolings with batch_norm and ReLU seasoning, but you shouldn't necessarily stop there.
#    * [Inception family](https://hacktilldawn.com/2016/09/25/inception-modules-explained-and-implemented/), [ResNet family](https://towardsdatascience.com/an-overview-of-resnet-and-its-variants-5281e2f56035?gi=9018057983ca), [Densely-connected convolutions (exotic)](https://arxiv.org/abs/1608.06993), [Capsule networks (exotic)](https://arxiv.org/abs/1710.09829)
#    * Please do try a few simple architectures before you go for resnet-152.
#    * Warning! Training convolutional networks can take long without GPU. That's okay.
#      * If you are CPU-only, we still recomment that you try a simple convolutional architecture
#      * a perfect option is if you can set it up to run at nighttime and check it up at the morning.
#      * Make reasonable layer size estimates. A 128-neuron first convolution is likely an overkill.
#      * __To reduce computation__ time by a factor in exchange for some accuracy drop, try using __stride__ parameter. A stride=2 convolution should take roughly 1/4 of the default (stride=1) one.
#
#
# ### Data augmemntation
#    * getting 5x as large dataset for free is a great
#      * Zoom-in+slice = move
#      * Rotate+zoom(to remove black stripes)
#      * Add Noize (gaussian or bernoulli)
#    * Simple way to do that (if you have PIL/Image):
#      * ```from scipy.misc import imrotate,imresize```
#      * and a few slicing
#      * Other cool libraries: cv2, skimake, PIL/Pillow
#    * A more advanced way is to use torchvision transforms:
#     ```
#     transform_train = transforms.Compose([
#         transforms.RandomCrop(32, padding=4),
#         transforms.RandomHorizontalFlip(),
#         transforms.ToTensor(),
#         transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
#     ])
#     trainset = torchvision.datasets.CIFAR10(root=path_to_cifar_like_in_seminar, train=True, download=True, transform=transform_train)
#     trainloader = torch.utils.data.DataLoader(trainset, batch_size=128, shuffle=True, num_workers=2)
#
#     ```
#    * Or use this tool from Keras (requires theano/tensorflow): [tutorial](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), [docs](https://keras.io/preprocessing/image/)
#    * Stay realistic. There's usually no point in flipping dogs upside down as that is not the way you usually see them.
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```
#
# ```

# %% [markdown]
# Let's build now a custom network for CIFAR10 classification problem:

# %%
del model, opt, train_loader, test_loader

# %%
from torchvision import transforms
means = np.array((0.4914, 0.4822, 0.4465))
stds = np.array((0.2023, 0.1994, 0.2010))

transform_augment = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomRotation([-30, 30]),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(means, stds),
])

# %%
from torchvision.datasets import CIFAR10
from torch.utils.data import DataLoader, random_split
train_loader = CIFAR10("./cifar_data/", train=True, transform=transform_augment)
batch_size = 32

#Split the dataset into training and validation datasets (90% train, 10% val)
train_size = int(0.9 * len(train_loader))
val_size = len(train_loader) - train_size
train_dataset, val_dataset = random_split(train_loader, [train_size, val_size])

#Create DataLoaders for training and validation
train_batch_gen = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=1)
val_batch_gen = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=1)

# %%
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(means, stds),
])

#Define test loader with the transform_test
test_loader = CIFAR10("./cifar_data/", train=False, transform=transform_test)
test_batch_gen = DataLoader(test_loader, batch_size=32, shuffle=False, num_workers=1)

# %%
model = nn.Sequential(
    #Convulotional layer 1
    nn.Conv2d(in_channels=3, out_channels=64, kernel_size=(5,5)),  # 3x3 convolution with 32 filters
    nn.BatchNorm2d(64),  # Batch Norm after convolution
    nn.LeakyReLU(),
    nn.MaxPool2d(2),  # 2x2 pooling

    #Convulotional layer 2
    nn.Conv2d(in_channels=64, out_channels=128, kernel_size=(3,3)),  # 3x3 convolution with 64 filters
    nn.BatchNorm2d(128),  # Batch Norm after convolution
    nn.LeakyReLU(),
    nn.MaxPool2d(2),  # 2x2 pooling

    Flatten(),
    nn.Linear(128*6*6, 512),  # Adjust input size for flattened layer
    nn.BatchNorm1d(512),  # Batch Norm after dense layer
    nn.LeakyReLU(),
    nn.Dropout(0.1),  # 10% dropout
    nn.Linear(512, 10)  # Output dense layer with 10 classes
).to(device=device)

# Training loop (uses Adam optimizer)
opt = torch.optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# In the model up above I upgraded the previously tried network to be able to classify the given dataset of images:
# 1. Two  `convolutional layers`, the first is `5x5` with `64` filters, and the second is `3x3` with `128` filters.
# 2. Two `2x2 pooling` following the convolutional layers.
# 3. A dense layer of 512 neurones.
# 4. `10% dropout` to avoid overfitting (increasing it reduced the accuracy).
# 5. Used the `Adam optimizer` with a learning rate of `0.001` (sometimes `0.0005`, but lower than `0.001` reduced accuracy).
# 6. `Batch normalization` after each layer.
# 7. Training with `90%` of the augmented data from `CIFAR` (training set), and validating with the left `10%`.
# 8 Training for `50` epochs on average, and a batch size of `32`.

# %% [markdown]
# These options were chosen through multiple trials.

# %%
train_loss = []
val_accuracy = []

num_epochs = 100
best_accuracy = -np.inf
best_epoch = -1

for epoch in range(num_epochs):
    start_time = time.time()
    model.train(True)
    #for X_batch, y_batch in iterate_minibatches(X_train, y_train, batch_size):
    for X_batch, y_batch in train_batch_gen:
        loss = compute_loss(X_batch, y_batch)
        loss.backward()
        opt.step()
        opt.zero_grad()
        train_loss.append(loss.cpu().data.numpy())

    model.train(False)
    for X_batch, y_batch in val_batch_gen:
        logits = model(torch.as_tensor(X_batch, dtype=torch.float32, device=device))
        y_pred = logits.max(1)[1].cpu().data.numpy()
        val_accuracy.append(np.mean(y_batch.data.numpy() == y_pred))

    print(f"Epoch {epoch + 1} of {num_epochs} took {time.time() - start_time:.3f}s")
    print(f"  training loss (in-iteration): \t{np.mean(train_loss[-len(X_train) // batch_size :]):.6f}")
    print(f"  validation accuracy: \t\t\t{np.mean(val_accuracy[-len(X_val) // batch_size :]) * 100:.2f} %")
# Out:
# Epoch 1 of 100 took 35.596s
#   training loss (in-iteration): 	1.495725
#   validation accuracy: 			48.51 %
# Epoch 2 of 100 took 33.484s
#   training loss (in-iteration): 	1.283294
#   validation accuracy: 			53.05 %
# Epoch 3 of 100 took 44.819s
#   training loss (in-iteration): 	1.171911
#   validation accuracy: 			57.52 %
# Epoch 4 of 100 took 38.558s
#   training loss (in-iteration): 	1.099805
#   validation accuracy: 			60.10 %
# Epoch 5 of 100 took 37.633s
#   training loss (in-iteration): 	1.036977
#   validation accuracy: 			63.29 %
# Epoch 6 of 100 took 41.854s
#   training loss (in-iteration): 	1.000320
#   validation accuracy: 			64.34 %
# Epoch 7 of 100 took 34.686s
#   training loss (in-iteration): 	0.959293
#   validation accuracy: 			66.11 %
# Epoch 8 of 100 took 34.501s
#   training loss (in-iteration): 	0.936316
#   validation accuracy: 			68.12 %
# Epoch 9 of 100 took 35.697s
#   training loss (in-iteration): 	0.904097
#   validation accuracy: 			68.82 %
# Epoch 10 of 100 took 33.343s
#   training loss (in-iteration): 	0.883170
#   validation accuracy: 			69.34 %
# Epoch 11 of 100 took 34.954s
#   training loss (in-iteration): 	0.861414
#   validation accuracy: 			69.75 %
# Epoch 12 of 100 took 33.433s
#   training loss (in-iteration): 	0.840785
#   validation accuracy: 			70.59 %
# Epoch 13 of 100 took 35.117s
#   training loss (in-iteration): 	0.825256
#   validation accuracy: 			71.63 %
# Epoch 14 of 100 took 33.667s
#   training loss (in-iteration): 	0.800319
#   validation accuracy: 			71.70 %
# Epoch 15 of 100 took 35.343s
#   training loss (in-iteration): 	0.793105
#   validation accuracy: 			72.28 %
# Epoch 16 of 100 took 34.275s
#   training loss (in-iteration): 	0.777299
#   validation accuracy: 			72.43 %
# Epoch 17 of 100 took 34.500s
#   training loss (in-iteration): 	0.762667
#   validation accuracy: 			72.09 %
# Epoch 18 of 100 took 35.297s
#   training loss (in-iteration): 	0.755557
#   validation accuracy: 			72.92 %
# Epoch 19 of 100 took 33.783s
#   training loss (in-iteration): 	0.749864
#   validation accuracy: 			73.64 %
# Epoch 20 of 100 took 35.487s
#   training loss (in-iteration): 	0.733027
#   validation accuracy: 			74.18 %
# Epoch 21 of 100 took 33.367s
#   training loss (in-iteration): 	0.727753
#   validation accuracy: 			74.30 %
# Epoch 22 of 100 took 34.337s
#   training loss (in-iteration): 	0.720820
#   validation accuracy: 			73.98 %
# Epoch 23 of 100 took 33.467s
#   training loss (in-iteration): 	0.714397
#   validation accuracy: 			74.57 %
# Epoch 24 of 100 took 33.828s
#   training loss (in-iteration): 	0.700963
#   validation accuracy: 			74.85 %
# Epoch 25 of 100 took 32.920s
#   training loss (in-iteration): 	0.684601
#   validation accuracy: 			74.68 %
# Epoch 26 of 100 took 33.623s
#   training loss (in-iteration): 	0.688873
#   validation accuracy: 			74.51 %
# Epoch 27 of 100 took 32.660s
#   training loss (in-iteration): 	0.673013
#   validation accuracy: 			74.66 %
# Epoch 28 of 100 took 32.920s
#   training loss (in-iteration): 	0.668985
#   validation accuracy: 			75.39 %
# Epoch 29 of 100 took 32.642s
#   training loss (in-iteration): 	0.666467
#   validation accuracy: 			75.43 %
# Epoch 30 of 100 took 33.040s
#   training loss (in-iteration): 	0.658821
#   validation accuracy: 			75.55 %
# Epoch 31 of 100 took 33.627s
#   training loss (in-iteration): 	0.653179
#   validation accuracy: 			75.94 %
# Epoch 32 of 100 took 34.565s
#   training loss (in-iteration): 	0.647876
#   validation accuracy: 			75.86 %
# Epoch 33 of 100 took 35.115s
#   training loss (in-iteration): 	0.635196
#   validation accuracy: 			75.90 %
# Epoch 34 of 100 took 34.053s
#   training loss (in-iteration): 	0.634812
#   validation accuracy: 			76.56 %
# Epoch 35 of 100 took 33.407s
#   training loss (in-iteration): 	0.635660
#   validation accuracy: 			77.00 %
# Epoch 36 of 100 took 34.578s
#   training loss (in-iteration): 	0.631558
#   validation accuracy: 			76.65 %
# Epoch 37 of 100 took 33.806s
#   training loss (in-iteration): 	0.620186
#   validation accuracy: 			76.53 %
# Epoch 38 of 100 took 35.107s
#   training loss (in-iteration): 	0.619865
#   validation accuracy: 			77.06 %
# Epoch 39 of 100 took 34.223s
#   training loss (in-iteration): 	0.614259
#   validation accuracy: 			76.82 %
# Epoch 40 of 100 took 34.819s
#   training loss (in-iteration): 	0.603084
#   validation accuracy: 			76.42 %
# Epoch 41 of 100 took 33.780s
#   training loss (in-iteration): 	0.606207
#   validation accuracy: 			76.80 %
# Epoch 42 of 100 took 34.542s
#   training loss (in-iteration): 	0.596281
#   validation accuracy: 			76.85 %
# Epoch 43 of 100 took 33.321s
#   training loss (in-iteration): 	0.588020
#   validation accuracy: 			77.50 %
# Epoch 44 of 100 took 34.523s
#   training loss (in-iteration): 	0.588832
#   validation accuracy: 			77.78 %
# Epoch 45 of 100 took 33.595s
#   training loss (in-iteration): 	0.585441
#   validation accuracy: 			77.68 %
# Epoch 46 of 100 took 34.974s
#   training loss (in-iteration): 	0.580714
#   validation accuracy: 			77.73 %
# Epoch 47 of 100 took 33.560s
#   training loss (in-iteration): 	0.582014
#   validation accuracy: 			77.20 %
# Epoch 48 of 100 took 34.736s
#   training loss (in-iteration): 	0.572787
#   validation accuracy: 			77.11 %
# Epoch 49 of 100 took 34.241s
#   training loss (in-iteration): 	0.574325
#   validation accuracy: 			77.03 %
# Epoch 50 of 100 took 34.425s
#   training loss (in-iteration): 	0.565300
#   validation accuracy: 			77.21 %
# Epoch 51 of 100 took 34.325s
#   training loss (in-iteration): 	0.564984
#   validation accuracy: 			78.11 %
# Epoch 52 of 100 took 34.292s
#   training loss (in-iteration): 	0.562843
#   validation accuracy: 			78.00 %
# Epoch 53 of 100 took 34.276s
#   training loss (in-iteration): 	0.562635
#   validation accuracy: 			77.66 %
# Epoch 54 of 100 took 33.860s
#   training loss (in-iteration): 	0.558766
#   validation accuracy: 			77.63 %
# Epoch 55 of 100 took 34.468s
#   training loss (in-iteration): 	0.550213
#   validation accuracy: 			77.95 %
# Epoch 56 of 100 took 33.680s
#   training loss (in-iteration): 	0.551107
#   validation accuracy: 			77.82 %
# Epoch 57 of 100 took 34.783s
#   training loss (in-iteration): 	0.553706
#   validation accuracy: 			78.02 %
# Epoch 58 of 100 took 33.501s
#   training loss (in-iteration): 	0.549344
#   validation accuracy: 			78.47 %
# Epoch 59 of 100 took 34.730s
#   training loss (in-iteration): 	0.540140
#   validation accuracy: 			78.28 %
# Epoch 60 of 100 took 34.602s
#   training loss (in-iteration): 	0.543314
#   validation accuracy: 			78.84 %
# Epoch 61 of 100 took 35.747s
#   training loss (in-iteration): 	0.536726
#   validation accuracy: 			78.37 %
# Epoch 62 of 100 took 35.387s
#   training loss (in-iteration): 	0.539449
#   validation accuracy: 			77.89 %
# Epoch 63 of 100 took 34.301s
#   training loss (in-iteration): 	0.536234
#   validation accuracy: 			78.49 %
# Epoch 64 of 100 took 35.142s
#   training loss (in-iteration): 	0.531244
#   validation accuracy: 			78.65 %
# Epoch 65 of 100 took 34.042s
#   training loss (in-iteration): 	0.525539
#   validation accuracy: 			78.46 %
# Epoch 66 of 100 took 34.826s
#   training loss (in-iteration): 	0.531027
#   validation accuracy: 			78.58 %
# Epoch 67 of 100 took 33.769s
#   training loss (in-iteration): 	0.523889
#   validation accuracy: 			78.49 %
# Epoch 68 of 100 took 34.610s
#   training loss (in-iteration): 	0.524517
#   validation accuracy: 			78.78 %
# Epoch 69 of 100 took 33.529s
#   training loss (in-iteration): 	0.519069
#   validation accuracy: 			79.10 %
# Epoch 70 of 100 took 34.814s
#   training loss (in-iteration): 	0.514873
#   validation accuracy: 			78.87 %
# Epoch 71 of 100 took 33.434s
#   training loss (in-iteration): 	0.515134
#   validation accuracy: 			78.85 %
# Epoch 72 of 100 took 34.659s
#   training loss (in-iteration): 	0.510823
#   validation accuracy: 			78.99 %
# Epoch 73 of 100 took 33.980s
#   training loss (in-iteration): 	0.507461
#   validation accuracy: 			78.95 %
# Epoch 74 of 100 took 34.618s
#   training loss (in-iteration): 	0.507063
#   validation accuracy: 			78.77 %
# Epoch 75 of 100 took 35.045s
#   training loss (in-iteration): 	0.503479
#   validation accuracy: 			78.99 %
# Epoch 76 of 100 took 34.328s
#   training loss (in-iteration): 	0.505481
#   validation accuracy: 			78.82 %
# Epoch 77 of 100 took 35.743s
#   training loss (in-iteration): 	0.498861
#   validation accuracy: 			78.93 %
# Epoch 78 of 100 took 34.347s
#   training loss (in-iteration): 	0.500457
#   validation accuracy: 			79.54 %
# Epoch 79 of 100 took 36.533s
#   training loss (in-iteration): 	0.498711
#   validation accuracy: 			79.48 %
# Epoch 80 of 100 took 35.448s
#   training loss (in-iteration): 	0.501194
#   validation accuracy: 			79.07 %
# Epoch 81 of 100 took 34.569s
#   training loss (in-iteration): 	0.498456
#   validation accuracy: 			78.88 %
# Epoch 82 of 100 took 35.284s
#   training loss (in-iteration): 	0.494037
#   validation accuracy: 			79.30 %
# Epoch 83 of 100 took 35.195s
#   training loss (in-iteration): 	0.487920
#   validation accuracy: 			79.28 %
# Epoch 84 of 100 took 35.623s
#   training loss (in-iteration): 	0.487729
#   validation accuracy: 			78.91 %
# Epoch 85 of 100 took 35.193s
#   training loss (in-iteration): 	0.486353
#   validation accuracy: 			79.03 %
# Epoch 86 of 100 took 34.098s
#   training loss (in-iteration): 	0.489732
#   validation accuracy: 			79.22 %
# Epoch 87 of 100 took 35.192s
#   training loss (in-iteration): 	0.481516
#   validation accuracy: 			79.64 %
# Epoch 88 of 100 took 34.037s
#   training loss (in-iteration): 	0.484267
#   validation accuracy: 			79.81 %
# Epoch 89 of 100 took 35.364s
#   training loss (in-iteration): 	0.485205
#   validation accuracy: 			79.87 %
# Epoch 90 of 100 took 34.479s
#   training loss (in-iteration): 	0.481112
#   validation accuracy: 			80.03 %
# Epoch 91 of 100 took 35.426s
#   training loss (in-iteration): 	0.484846
#   validation accuracy: 			79.96 %
# Epoch 92 of 100 took 35.581s
#   training loss (in-iteration): 	0.470438
#   validation accuracy: 			79.53 %
# Epoch 93 of 100 took 33.950s
#   training loss (in-iteration): 	0.471212
#   validation accuracy: 			79.16 %
# Epoch 94 of 100 took 35.184s
#   training loss (in-iteration): 	0.472003
#   validation accuracy: 			79.39 %
# Epoch 95 of 100 took 34.239s
#   training loss (in-iteration): 	0.470982
#   validation accuracy: 			79.69 %
# Epoch 96 of 100 took 35.436s
#   training loss (in-iteration): 	0.478652
#   validation accuracy: 			80.02 %
# Epoch 97 of 100 took 34.615s
#   training loss (in-iteration): 	0.459254
#   validation accuracy: 			80.36 %
# Epoch 98 of 100 took 35.812s
#   training loss (in-iteration): 	0.465619
#   validation accuracy: 			80.27 %
# Epoch 99 of 100 took 36.351s
#   training loss (in-iteration): 	0.470409
#   validation accuracy: 			79.74 %
# Epoch 100 of 100 took 35.383s
#   training loss (in-iteration): 	0.463001
#   validation accuracy: 			79.59 %

# %% [markdown]
# Here you can load the best saved model. It was trained with the ratios 90%-10% for training and validation from the CIFAR data. he model was trained for a 100 epochs to reach 85% accuracy, although 50 epochs seem to be enough to get it to around 83% accuracy.

# %%
model_url = 'https://drive.google.com/file/d/1G38FlpnzH0SG1HHztgrc_9xsiOTgDmvb/view?usp=sharing'
model_url = 'https://drive.google.com/uc?id='+model_url.split('/')[-2]
load_best_model = True
if load_best_model:
    print('Loading the best model...')
    # !wget -O 'best_model_state.pt' '{model_url}'
    model_dict = torch.load('best_model_state.pt', weights_only=True, map_location=torch.device(device))
    model.load_state_dict(model_dict)
# Out:
# Loading the best model...
# --2024-10-08 08:24:31--  https://drive.google.com/uc?id=1G38FlpnzH0SG1HHztgrc_9xsiOTgDmvb
# Resolving drive.google.com (drive.google.com)... 74.125.196.100, 74.125.196.139, 74.125.196.138, ...
# Connecting to drive.google.com (drive.google.com)|74.125.196.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1G38FlpnzH0SG1HHztgrc_9xsiOTgDmvb [following]
# --2024-10-08 08:24:31--  https://drive.usercontent.google.com/download?id=1G38FlpnzH0SG1HHztgrc_9xsiOTgDmvb
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 172.217.204.132, 2607:f8b0:400c:c15::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|172.217.204.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9793486 (9.3M) [application/octet-stream]
# Saving to: ‘best_model_state.pt’
#
# best_model_state.pt 100%[===================>]   9.34M  32.5MB/s    in 0.3s
#
# 2024-10-08 08:24:38 (32.5 MB/s) - ‘best_model_state.pt’ saved [9793486/9793486]

# %%
model.train(False) # disable dropout / use averages for batch_norm
test_batch_acc = []
#for X_batch, y_batch in iterate_minibatches(X_test, y_test, 500):
for X_batch, y_batch in test_batch_gen:
    logits = model(torch.as_tensor(X_batch, dtype=torch.float32, device=device))
    y_pred = logits.max(1)[1].cpu().data.numpy()
    test_batch_acc.append(np.mean(y_batch.data.numpy() == y_pred))

test_accuracy = np.mean(test_batch_acc)

print("Final results:")
print("  test accuracy:\t\t{:.2f} %".format(
    test_accuracy * 100))

if test_accuracy * 100 > 95:
    print("Double-check, than consider applying for NIPS'17. SRSly.")
elif test_accuracy * 100 > 90:
    print("U'r freakin' amazin'!")
elif test_accuracy * 100 > 80:
    print("Achievement unlocked: 110lvl Warlock!")
elif test_accuracy * 100 > 70:
    print("Achievement unlocked: 80lvl Warlock!")
elif test_accuracy * 100 > 60:
    print("Achievement unlocked: 70lvl Warlock!")
elif test_accuracy * 100 > 50:
    print("Achievement unlocked: 60lvl Warlock!")
else:
    print("We need more magic! Follow instructons below")
# Out:
# Final results:
#   test accuracy:		85.20 %
# Achievement unlocked: 110lvl Warlock!

# %% [markdown]
# Saving the best models:

# %%
max_accuracy = 80.0
accuracy = test_accuracy*100
if accuracy > max_accuracy:
    torch.save(model.state_dict(), f'model_acc_{str(round(accuracy, 2)).replace(".","-")}.pt')
